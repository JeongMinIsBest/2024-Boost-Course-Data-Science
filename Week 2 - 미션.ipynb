# %% [markdown]
# # 2주차 미션

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/corazzon/boostcourse-ds-510/master/data/medical_201909.csv.zip", low_memory=False)
df.shape
# Out:
# (91335, 39)

# %%
df.head(3)
# Out:
#      상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 0  19956873     하나산부인과  NaN         S       의료       S01       병원    S01B10
# 1  20024149   타워광명내과의원  NaN         S       의료       S01       병원    S01B07
# 2  20152277  조정현신경외과의원  NaN         S       의료       S01       병원    S01B15
#
#   상권업종소분류명 표준산업분류코드  ...                     건물관리번호      건물명  \
# 0     산부인과   Q86201  ...  4127310900110810000010857  산호한양아파트
# 1    내과/외과   Q86201  ...  1168011800104670014000001      NaN
# 2     신경외과   Q86201  ...  4139013200117400001017064    한라프라자
#
#                  도로명주소     구우편번호    신우편번호  동정보  층정보  호정보          경도  \
# 0   경기도 안산시 단원구 달미로 10  425764.0  15236.0  NaN  NaN  NaN  126.814295
# 1  서울특별시 강남구 언주로30길 39  135270.0   6292.0  NaN    4  NaN  127.053198
# 2    경기도 시흥시 중심상가로 178  429450.0  15066.0  NaN  NaN  NaN  126.734841
#
#           위도
# 0  37.336344
# 1  37.488742
# 2  37.344955
#
# [3 rows x 39 columns]

# %% [markdown]
# 📌 Q1. 전국 시도별 약국수를 구해주세요!
#
# 상권업종소분류명이 약국인 것을 찾아 빈도수를 구해주세요. 이 때, value_counts, groupby, pivot_table 등 다양한 집계 방법을 통해 구해볼 수 있습니다. 각자 구하기 편한 방법을 통해 빈도수를 구합니다.
# 다음의 결과가 나오도록 구합니다.

# %%
pharmacy_df = df[df["상권업종소분류명"] == "약국"]
pharmacy_df
# Out:
#          상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 4      20364049  더블유스토어수지점  수지점         S       의료       S02   약국/한약방
# 10     21057519       민생약국  NaN         S       의료       S02   약국/한약방
# 15     21006553       상명약국  NaN         S       의료       S02   약국/한약방
# 16     21026027       햇살약국  NaN         S       의료       S02   약국/한약방
# 24     21228644      화정하나로  NaN         S       의료       S02   약국/한약방
# ...         ...        ...  ...       ...      ...       ...      ...
# 91312  16131397      큰나무약국  NaN         S       의료       S02   약국/한약방
# 91321  16130841       복음약국  NaN         S       의료       S02   약국/한약방
# 91322  16091491  설연화한복감성약방  NaN         S       의료       S02   약국/한약방
# 91324  16109731      위례수약국  NaN         S       의료       S02   약국/한약방
# 91330  16196725      온누리약국  베스트         S       의료       S02   약국/한약방
#
#       상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호        건물명  \
# 4        S02A01       약국   G47811  ...  4146510100107120002026238        NaN
# 10       S02A01       약국   G47811  ...  4889046030200780002048274        NaN
# 15       S02A01       약국   G47811  ...  4713010800103400004022515        NaN
# 16       S02A01       약국   G47811  ...  4117310100111010002005070    샛별한양아파트
# 24       S02A01       약국   G47811  ...  4128112300109690000012921        동원텔
# ...         ...      ...      ...  ...                        ...        ...
# 91312    S02A01       약국   G47811  ...  4128110600107000011013834      신원당빌딩
# 91321    S02A01       약국   G47811  ...  2729012400102760000029818  그린맨션3차아파트
# 91322    S02A01       약국   G47811  ...  1126010400101740001009985        NaN
# 91324    S02A01       약국   G47811  ...  4113110800101810002000002        NaN
# 91330    S02A01       약국   G47811  ...  3017011200115070000021096        NaN
#
#                          도로명주소     구우편번호    신우편번호  동정보  층정보  호정보          경도  \
# 4           경기도 용인시 수지구 문정로 32  448170.0  16837.0  NaN    1  NaN  127.095522
# 10     경상남도 합천군 용주면 월평길 149-35  678912.0  50212.0  NaN  NaN  NaN  128.118615
# 15            경상북도 경주시 금성로 281  780943.0  38156.0  NaN    1  NaN  129.206670
# 16          경기도 안양시 동안구 달안로 61  431719.0  14043.0  NaN  NaN  NaN  126.948953
# 24          경기도 고양시 덕양구 화정로 47  412737.0  10497.0  NaN    3  NaN  126.831406
# ...                        ...       ...      ...  ...  ...  ...         ...
# 91312    경기도 고양시 덕양구 고양대로 1361  412807.0  10464.0  NaN    1  NaN  126.835684
# 91321      대구광역시 달서구 구마로36길 33  704752.0  42735.0  301  NaN  105  128.547352
# 91322         서울특별시 중랑구 공릉로 28  131848.0   2034.0  NaN  NaN  NaN  127.078082
# 91324     경기도 성남시 수정구 위례서일로 18  461210.0  13647.0  NaN    1  NaN  127.137870
# 91330          대전광역시 서구 문예로 67  302831.0  35240.0  NaN  NaN  NaN  127.389865
#
#               위도
# 4      37.323528
# 10     35.575962
# 15     35.842804
# 16     37.396502
# 24     37.635165
# ...          ...
# 91312  37.655048
# 91321  35.836250
# 91322  37.613194
# 91324  37.465260
# 91330  36.352728
#
# [18964 rows x 39 columns]

# %%
pharmacy_df["시도명"].value_counts()
# Out:
# 시도명
# 경기도        4510
# 서울특별시      3579
# 부산광역시      1130
# 경상남도       1017
# 인천광역시      1002
# 경상북도        915
# 대구광역시       870
# 전라북도        862
# 충청남도        830
# 전라남도        811
# 강원도         729
# 광주광역시       691
# 충청북도        648
# 대전광역시       603
# 울산광역시       362
# 제주특별자치도     226
# 세종특별자치시      99
# Name: count, dtype: int64

# %% [markdown]
# 📌 Q2. 여러분은 반려동물과 관련된 사업을 하는 스타트업에 취업을 하여 상권분석을 해달라는 요청을 받았습니다. 병원이나 약국은 인구나 유동인구가 많은 지역에 주로 위치하고 있습니다. 그렇다면 동물병원도 병원이나 약국이 많은 곳에 더 많이 있을까요?
#
# 빈도수를 구하고 시각화 하여 동물병원이 어느 지역에 많은지 분석해 주세요!
# 다음의 결과가 나오도록 구합니다.

# %%
animal_hospital = df[df["상권업종소분류명"] == "동물병원"]
animal_hospital
# Out:
#          상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 5      20809147      행신동물병원  NaN         S       의료       S04      수의업
# 12     21145534      목포동물병원  NaN         S       의료       S04      수의업
# 20     21085006      제일가축병원  NaN         S       의료       S04      수의업
# 25     21055738      축협동물병원  NaN         S       의료       S04      수의업
# 30     20970595    금광종합동물병원  NaN         S       의료       S04      수의업
# ...         ...         ...  ...       ...      ...       ...      ...
# 91172  16366207  동물에반하다동물병원  NaN         S       의료       S04      수의업
# 91174  16365867     반창꼬동물병원  NaN         S       의료       S04      수의업
# 91213  16131045      서진동물병원  NaN         S       의료       S04      수의업
# 91242  16109069    아크리스동물병원  NaN         S       의료       S04      수의업
# 91299  16108691     더블유동물병원  NaN         S       의료       S04      수의업
#
#       상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...                     건물관리번호    건물명  \
# 5        S04A02     동물병원   M73100  ...  4128112800106470014011094    NaN
# 12       S04A02     동물병원   M73100  ...  4611010200110500078000665    NaN
# 20       S04A02     동물병원   M73100  ...  4136037021102040012005537    NaN
# 25       S04A02     동물병원   M73100  ...  4671025025103420000000164    NaN
# 30       S04A02     동물병원   M73100  ...  4113110400100970003039318    NaN
# ...         ...      ...      ...  ...                        ...    ...
# 91172    S04A02     동물병원   M73100  ...  2826010400109490004000001    NaN
# 91174    S04A02     동물병원   M73100  ...  4163011400110490001000001    NaN
# 91213    S04A02     동물병원   M73100  ...  4513014400105010000028021  현대아파트
# 91242    S04A02     동물병원   M73100  ...  1168010500101600021015764   동화빌딩
# 91299    S04A02     동물병원   M73100  ...  1162010100106220074027662    NaN
#
#                              도로명주소     구우편번호    신우편번호  동정보  층정보  호정보  \
# 5              경기도 고양시 덕양구 행신로 147  412220.0  10517.0  NaN    1  NaN
# 12              전라남도 목포시 영산로 200-1  530806.0  58708.0  NaN    1  NaN
# 20     경기도 남양주시 퇴계원면 경춘북로558번길 7-7  472821.0  12126.0  NaN    1  NaN
# 25           전라남도 담양군 담양읍 삼거리길 8-6  517806.0  57347.0  NaN    1  NaN
# 30            경기도 성남시 수정구 산성대로 431  461801.0  13144.0  NaN    1  NaN
# ...                            ...       ...      ...  ...  ...  ...
# 91172       인천광역시 서구 크리스탈로102번길 22       NaN  22760.0  NaN    1  102
# 91174              경기도 양주시 옥정로 151  482130.0  11479.0  NaN  NaN  302
# 91213             전라북도 군산시 나운안2길 8  573778.0  54135.0  102  NaN  905
# 91242        서울특별시 강남구 봉은사로104길 10  135881.0   6170.0  NaN    3  NaN
# 91299             서울특별시 관악구 은천로 85  151826.0   8715.0  NaN  NaN  NaN
#
#                경도         위도
# 5      126.831632  37.619309
# 12     126.390244  34.799439
# 20     127.146600  37.647633
# 25     126.981972  35.310645
# 30     127.158972  37.450472
# ...           ...        ...
# 91172  126.639196  37.533858
# 91174  127.090349  37.815362
# 91213  126.705522  35.967977
# 91242  127.061898  37.513707
# 91299  126.944700  37.487048
#
# [3098 rows x 39 columns]

# %%
animal_hospital["시도명"].value_counts()
# Out:
# 시도명
# 경기도        992
# 서울특별시      557
# 인천광역시      193
# 경상북도       165
# 경상남도       161
# 부산광역시      153
# 충청남도       131
# 대구광역시      119
# 전라북도       111
# 강원도         85
# 대전광역시       77
# 전라남도        77
# 충청북도        75
# 광주광역시       71
# 울산광역시       61
# 제주특별자치도     46
# 세종특별자치시     13
# Name: count, dtype: int64

# %% [markdown]
# 📌Q3. 강남지역에는 다른 지역에 비해 피부과나 성형외과가 많아 보입니다. 실제로 해당 지역에 피부과나 성형외과가 다른 지역에 비해 전체 병원 수 중에서 어느 정도의 비율을 차지하고 있는지 알아보겠습니다.
#
# 서울에 소재한 병원 중 상권업종소분류명에 "피부" 나 "성형"이 들어간 분류명을 찾아 구해주세요!
# 피부과 성형외과 수 / 전체병원 수 로 비율을 구해주세요!
# 비율이 높은 순서대로 정렬되게 구해주세요!
# 수업에서 사용한 같은 CSV 파일을 사용하며 다음의 결과가 나오도록 구합니다.
# 소숫점 두 번째짜리까지 출력하는 방법은 pandas round 로 검색해서 사용법을 알아보세요!

# %%
special = df[(df["시도명"] == "서울특별시") & (df["상권업종중분류명"].str.contains("병원"))]
special.head(3)
# Out:
#      상가업소번호       상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 1  20024149  타워광명내과의원  NaN         S       의료       S01       병원    S01B07
# 8  20808534    코원성형외과  NaN         S       의료       S01       병원    S01B08
# 9  20755460  헬로스마일소아과  NaN         S       의료       S01       병원    S01B11
#
#   상권업종소분류명 표준산업분류코드  ...                     건물관리번호   건물명  \
# 1    내과/외과   Q86201  ...  1168011800104670014000001   NaN
# 8  정형/성형외과   Q86201  ...  1168010700105920004010990  이가빌딩
# 9      소아과   Q86201  ...  1168010800100390018000001  성도빌딩
#
#                   도로명주소     구우편번호   신우편번호  동정보 층정보  호정보          경도         위도
# 1   서울특별시 강남구 언주로30길 39  135270.0  6292.0  NaN   4  NaN  127.053198  37.488742
# 8     서울특별시 강남구 논현로 826  135893.0  6025.0  NaN   4  NaN  127.028531  37.522223
# 9  서울특별시 강남구 논현로131길 30  135010.0  6045.0  NaN   3  NaN  127.027878  37.514144
#
# [3 rows x 39 columns]

# %%
skin_plastic_hospital = special[special["상권업종소분류명"].str.contains("피부|성형")]
skin_plastic_hospital.head(3)
# Out:
#       상가업소번호       상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 8   20808534    코원성형외과  NaN         S       의료       S01       병원    S01B08
# 31  20872995  고운나라성형외과  NaN         S       의료       S01       병원    S01B08
# 44  20912401   아미가성형외과  NaN         S       의료       S01       병원    S01B08
#
#    상권업종소분류명 표준산업분류코드  ...                     건물관리번호   건물명  \
# 8   정형/성형외과   Q86201  ...  1168010700105920004010990  이가빌딩
# 31  정형/성형외과   Q86201  ...  1174010800100090005004868   NaN
# 44  정형/성형외과   Q86201  ...  1165010100109020001015305  원등빌딩
#
#                   도로명주소     구우편번호   신우편번호  동정보 층정보  호정보          경도         위도
# 8     서울특별시 강남구 논현로 826  135893.0  6025.0  NaN   4  NaN  127.028531  37.522223
# 31  서울특별시 강동구 천호대로 1032  134030.0  5379.0  NaN   3  NaN  127.126507  37.537333
# 44   서울특별시 서초구 방배로20길 4  137060.0  6664.0  NaN   3  NaN  126.995334  37.485498
#
# [3 rows x 39 columns]

# %%
total_hospital = special["시군구명"].value_counts(ascending=False)
total_hospital
# Out:
# 시군구명
# 강남구     2550
# 서초구     1196
# 송파구      748
# 동대문구     644
# 광진구      600
# 강서구      579
# 영등포구     516
# 은평구      506
# 노원구      503
# 강동구      494
# 성북구      470
# 마포구      456
# 중구       423
# 양천구      398
# 관악구      395
# 서대문구     379
# 종로구      343
# 동작구      342
# 성동구      339
# 중랑구      307
# 구로구      289
# 도봉구      275
# 강북구      259
# 용산구      222
# 금천구      173
# Name: count, dtype: int64

# %%
total_skin_plastic = skin_plastic_hospital["시군구명"].value_counts()
total_skin_plastic
# Out:
# 시군구명
# 강남구     603
# 서초구     200
# 송파구      48
# 마포구      40
# 영등포구     39
# 강서구      38
# 광진구      37
# 강동구      37
# 중구       31
# 은평구      31
# 서대문구     29
# 성북구      28
# 동대문구     27
# 양천구      26
# 노원구      26
# 중랑구      21
# 성동구      17
# 구로구      17
# 관악구      17
# 동작구      14
# 강북구      12
# 종로구      11
# 용산구      10
# 금천구       9
# 도봉구       5
# Name: count, dtype: int64

# %%
ratio = (total_skin_plastic / total_hospital).round(2)
ratio.sort_values(ascending=False)
# Out:
# 시군구명
# 강남구     0.24
# 서초구     0.17
# 마포구     0.09
# 영등포구    0.08
# 서대문구    0.08
# 강서구     0.07
# 강동구     0.07
# 중구      0.07
# 양천구     0.07
# 중랑구     0.07
# 성북구     0.06
# 송파구     0.06
# 구로구     0.06
# 은평구     0.06
# 광진구     0.06
# 노원구     0.05
# 성동구     0.05
# 금천구     0.05
# 용산구     0.05
# 강북구     0.05
# 동대문구    0.04
# 동작구     0.04
# 관악구     0.04
# 종로구     0.03
# 도봉구     0.02
# Name: count, dtype: float64

# %% [markdown]
# 📌Q4. 평균 기대수명이 점점 길어지면서 실버 의료 산업도 주목받고 있습니다. 여러분은 실버 의료 산업과 관련된 스타트업에 취업했습니다. 지도를 시각화하여 '노인/치매병원'이 주로 어디에 위치하고 있는지를 찾아보고자 합니다.
#
# folium 을 통해 지도에 전국의 '노인/치매병원'을 표시해 주세요!
# 다음과 같이 시각화 하며, folium 의 문서를 참고하여 다른 기능을 사용하여 좀 더 멋지게 지도를 꾸며도 좋습니다.
# folium 문서 : https://python-visualization.github.io/folium/quickstart.html

# %%
import folium

elderly_hospital = df[df["상권업종소분류명"].str.contains("노인|치매병원")]
elderly_hospital.head(2)
# Out:
#       상가업소번호      상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 21  21128898  다사랑요양병원  NaN         S       의료       S01       병원    S01B17
# 62  21511155      노경회  NaN         S       의료       S01       병원    S01B17
#
#    상권업종소분류명 표준산업분류코드  ...                     건물관리번호      건물명  \
# 21  노인/치매병원   Q86102  ...  2632010300101360002000001  다사랑요양병원
# 62  노인/치매병원   Q86102  ...  4623035023110240001000001      NaN
#
#                  도로명주소     구우편번호    신우편번호  동정보 층정보  호정보          경도         위도
# 21    부산광역시 북구 덕천로 339  616110.0  46610.0  NaN   1  NaN  129.040773  35.209154
# 62  전라남도 광양시 진월면 용소길 7  545851.0  57713.0  NaN   1  NaN  127.746981  34.986585
#
# [2 rows x 39 columns]

# %%
map = folium.Map(location=[elderly_hospital["위도"].mean(), elderly_hospital["경도"].mean()], zoom_start=8)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb41e1fd50e10a600792d328b0eacf6d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb41e1fd50e10a600792d328b0eacf6d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb41e1fd50e10a600792d328b0eacf6d = L.map(
#                 &quot;map_bb41e1fd50e10a600792d328b0eacf6d&quot;,
#                 {
#                     center: [36.322638410225366, 127.69216156637984],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8afdd1c1790bb6a7de0778e00d5bb94e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8afdd1c1790bb6a7de0778e00d5bb94e.addTo(map_bb41e1fd50e10a600792d328b0eacf6d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for idx, row in elderly_hospitals.iterrows():
    try:
        latitude = row["위도"]
        longitude = row["경도"]

        folium.Marker(
            location=[latitude, longitude],
            popup=row["상호명"],
            icon=folium.Icon(color='blue', icon='info-sign')
        ).add_to(map)
    except:
        continue

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb41e1fd50e10a600792d328b0eacf6d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb41e1fd50e10a600792d328b0eacf6d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb41e1fd50e10a600792d328b0eacf6d = L.map(
#                 &quot;map_bb41e1fd50e10a600792d328b0eacf6d&quot;,
#                 {
#                     center: [36.322638410225366, 127.69216156637984],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8afdd1c1790bb6a7de0778e00d5bb94e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8afdd1c1790bb6a7de0778e00d5bb94e.addTo(map_bb41e1fd50e10a600792d328b0eacf6d);
#
#
#             tile_layer_8afdd1c1790bb6a7de0778e00d5bb94e.addTo(map_bb41e1fd50e10a600792d328b0eacf6d);
#
#
#             var marker_d2b51b53408d9d1ee7344b136fb380c2 = L.marker(
#                 [35.2091539574761, 129.040772964856],
#                 {}
#             ).addTo(map_bb41e1fd50e10a600792d328b0eacf6d);
#
#
#             var icon_da158c43c278915743efb1aabbd09f0d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d2b51b53408d9d1ee7344b136fb380c2.setIcon(icon_da158c43c278915743efb1aabbd09f0d);
#
#
#         var popup_6ceaac0164ce180c028b15f0f926a55e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_deb15ceb49fadfab4b109c1dcaf336ad = $(`&lt;div id=&quot;html_deb15ceb49fadfab4b109c1dcaf336ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;다사랑요양병원&lt;/div&gt;`)[0];
#                 popup_6ceaac0164ce180c028b15f0f926a55e.setContent(html_deb15ceb49fadfab4b109c1dcaf336ad);
#
#
#
#         marker_d2b51b53408d9d1ee7344b136fb380c2.bindPopup(popup_6ceaac0164ce180c028b15f0f926a55e)
#         ;
#
#
#
#
#             var marker_996d941a9758c57d07fdcd1efaff37d4 = L.marker(
#                 [34.9865848568725, 127.746980976467],
#                 {}
#             ).addTo(map_bb41e1fd50e10a600792d328b0eacf6d);
#
#
#             var icon_0314182a54e49b024434014d6cca88aa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_996d941a9758c57d07fdcd1efaff37d4.setIcon(icon_0314182a54e49b024434014d6cca88aa);
#
#
#         var popup_a07afc4caaf104a8c1c66ce452c007e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dd2f33e1572b7a851616c22febe3f0e9 = $(`&lt;div id=&quot;html_dd2f33e1572b7a851616c22febe3f0e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;노경회&lt;/div&gt;`)[0];
#                 popup_a07afc4caaf104a8c1c66ce452c007e1.setContent(html_dd2f33e1572b7a851616c22febe3f0e9);
#
#
#
#         marker_996d941a9758c57d07fdcd1efaff37d4.bindPopup(popup_a07afc4caaf104a8c1c66ce452c007e1)
#         ;
#
#
#
#
#             var marker_ad0b288217995a04c5c4385b93c00202 = L.marker(
#                 [37.6936890859817, 126.780121523366],
#                 {}
#             ).addTo(map_bb41e1fd50e10a600792d328b0eacf6d);
#
#
#             var icon_aa9bcc54877a476a16fd58d0edf10228 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ad0b288217995a04c5c4385b93c00202.setIcon(icon_aa9bcc54877a476a16fd58d0edf10228);
#
#
#         var popup_72109430057823ae2b78cb98685d9914 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31f35fb7d681e28e2cb623c2bcee1a54 = $(`&lt;div id=&quot;html_31f35fb7d681e28e2cb623c2bcee1a54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;일산카네이션너싱홈&lt;/div&gt;`)[0];
#                 popup_72109430057823ae2b78cb98685d9914.setContent(html_31f35fb7d681e28e2cb623c2bcee1a54);
#
#
#
#         marker_ad0b288217995a04c5c4385b93c00202.bindPopup(popup_72109430057823ae2b78cb98685d9914)
#         ;
#
#
#
#
#             var marker_8fe9d7cd828b2d66d4208e8d25858ea2 = L.marker(
#                 [34.9910140897983, 127.460606294325],
#                 {}
#             ).addTo(map_bb41e1fd50e10a600792d328b0eacf6d);
#
#
#             var icon_96b5566cb486a139e22a6d3260922d81 = L.AwesomeM
